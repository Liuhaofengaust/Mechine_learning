# %% [markdown]
# # LSTM生成文本
# * 采样的策略 - 设置不同的softmax温度，对概率分布进行重新加权

# %% [markdown]
# ### 实现字符级的LSTM文本生成

# %%
# 下载并解析初始化文本文件
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 将字符序列向量化

# %%
# 提取60个字符组成的序列
maxlen = 60
# 每3个字符采样一个新序列
step = 3
# 保存所提取的序列
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i+maxlen])
    next_chars.append(text[i+maxlen])
print('Number of aequences:', len(sentences))

# 语料中唯一字符组成的列表
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

# 将字符进行one-hot编码
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of aequences: 200278
# Unique characters: 57

# %% [markdown]
# ### 构建网络

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
# 该loss函数对应one-hot编码
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ### 训练语言模型并从中采样
# * 给定目前已生成的文本，从模型中得到下一个字符的概率分布
# * 根据某个温度对分布进行重新加权
# * 根据重新加权后的分布对下一个字符进行随机采样
# * 将字符添加到文本末尾

# %%
# 给定模型预测，采样下一个字符的函数
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ### 文本生成循环

# %%
import random
import sys


for epoch in range(1, 60):
    print('epoch', epoch)
    # 将模型在数据上拟合一次
    model.fit(x, y, batch_size=128, epochs=1)
    # 随机选择一个文本种子
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--Generating with seed:“' + generated_text + "”")
    # 尝试一系列不同的采样温度
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----temperature:', temperature)
        sys.stdout.write(generated_text)
    
        # 从种子文本开始生成400个字符
        for i in range(400):
            # 对目标字符进行one-hot编码
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
        
            # 对下一个字符进行采样
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
        
            generated_text += next_char
            generated_text = generated_text[1:]
        
            sys.stdout.write(next_char)
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 152s 758us/step - loss: 1.6146
# --Generating with seed:“emselves by piety to a seemingly higher order of things, and”
# ----temperature: 0.2
# emselves by piety to a seemingly higher order of things, and the condition of the fact as a decicial in the sense and the restance of the sense and the pression of the sense and the world the sense and the sense as the fact as the self-conditions of the condition of the stronged to the self-conditions of the sense and the sense and the self-tood to the self-for the struck, and the sense and the sense and the charm to the stronger to the self-conditions of
# ----temperature: 0.5
# nse and the charm to the stronger to the self-conditions of the moral have to the science and personal art in a honever, a stakeness of the barity and and be a pression of the sense enough of the fact to the prestation of sacrifice of in the philosophy of the gevilation of the former stronger and destrent to the strutgnd to own and wholly the more are a the most the most cast is will for the deely to the such as not to have weart and himself to say to cont
# ----temperature: 1.0
#  to the such as not to have weart and himself to say to contempt and eachumant from eye geed not they
# somec1ung cifters to be powerting to the
# bring there atblaess, for the recentence ones cases disgutend, in schoried, on a resticiarly expect a selving. we masters and chumpsebjul one time, expien denjugef. clay be p?onosities, an aptirispes songz" enthe, the past inspined
# of mone, smirhions
# that  keless which scient of the
# bor to herefory in
# a
# the freed al
# ----temperature: 1.2
# keless which scient of the
# bor to herefory in
# a
# the freed alone,ced ficurus befintaons
# on soulx. if
# all the teinenisional noble.
# more trush berie
# wimles lo=gance, reservess bee) f.ee to sess wind effectous
# enoug, and phinesif.
#
#
# apleatel glore, is didtern of the servisy whings. a
# wiswing to a therefore , nonghtumentianr beitness.
# tlu
# tzale, in the struke of for the faerh elcases sangces. thpreaver fa cexisike vircic in will nom of tle personttly to
# duyses
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 160s 800us/step - loss: 1.5264
# --Generating with seed:“ tones; gloomy,
# regular, restraining exhortations from a pri”
# ----temperature: 0.2
#  tones; gloomy,
# regular, restraining exhortations from a prictic and strong the moral as the sensition of the sensition of the sensition of the present in the sensition of the sensition of the sensition of the sensition of the strong the same the present the moral and the present it is not himself in the sensition of the sensition of the sensition of the sensition of the sensition of the moral present it is the sensition of the sensition, and all the sensi
# ----temperature: 0.5
# sent it is the sensition of the sensition, and all the sensition of discovertary with a premation of souls of the absequence gain the trate
# of men and the bord
# and respect, the man is the contralic to the souls and the world faith from the indematicous in soulse of the serve and beding the individual to the present with the sentiments and the same mind feeling in its, is the conscience, this souls" even the
# moral have a more down even of men, and man, the
# ----temperature: 1.0
# " even the
# moral have a more down even of men, and man, the may palt, in individual, it it is not to galkog--who utind nothing to its so tame: again; have
# has bothish modern understand- bjendatubles of villish with this or "poliees the
# pribemmated ettechable long sametition his must sugher its
# selfing, in bring
# to the god, a lichments--and our intrifact confrimes, with
# midslation, and histlich--is only a favourable, how be it was
# elives affear decimed to p
# ----temperature: 1.2
#  only a favourable, how be it was
# elives affear decimed to pain hot does metaphystils, it asy sarvation. even a percedpes xedious and
# ibvusuahle a fentially
# self-convelt himself when
# be being at abviale, a modent, un onequable with nacks. inslive of hise something wholly-yether books in shet-telfed that who depressing, ought from refrome, as
# grandable truthing app dewach heart: cause
# moway id andism, the mithous must
# creaplesed viewen manner!
#
# ovinr for th
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 161s 805us/step - loss: 1.4816
# --Generating with seed:“man thinks he sees it self-evidently. the problem for him is”
# ----temperature: 0.2
# man thinks he sees it self-evidently. the problem for him is a man in the same and the same and the same all the same and the sentiments of the consequent of all the same all the same and the problem of the same also an existence to an and the sentiments of the sentiments of an all the suble that the same and the same and the same and all the sentiments and all the same of the have in the same and to the same and the same and so in the same and also in the
# ----temperature: 0.5
#  to the same and the same and so in the same and also in the consequents of the self-knows and all these good it of all souls an indifferent to the such example to discoveral reason--and also the substence and pression to be such a pression of the reality, as the
# happiness of admire and such a stool of the superititic and above his
# also this still problem and instinction and sming there are not of the truth the most consequent to rewards the same so have a
# ----temperature: 1.0
#  the truth the most consequent to rewards the same so have as
# moralities and people. "the exporiness
# woman is exhition of vidues.
#
# 2, , "one fart of itly and the philosophyly, hus anralet master what which often more danger, woman a-houbd mentihed, and lofoon, or more extrection of attained tenity pardbises irestapes-exters, the waotime; different. liped
# framble of listious.
#
#
# yesse feels anfullists, and taste and rea to hours to looks(trans religion to he
# ----temperature: 1.2
# ts, and taste and rea to hours to looks(trans religion to he slove--by readt, effe-ca happin, that reasilation.= elses too
# which possib no isist as an rights of standide classes froct
# of
# cwerments--i mahe which, now confection" as according muther-obyenc to the
# hus. and
# accomnaturaginal skeptesiags-ack of
# they sins the
# mislioubly, whetether purits bining this (enough peepidion--and roctidesing ther
# fe tahtrae of problentlies= of merely
# cantinuss of so,
# reb
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 154s 771us/step - loss: 1.4514
# --Generating with seed:“ the unavoidable
# filth of all political agitation. the brahm”
# ----temperature: 0.2
#  the unavoidable
# filth of all political agitation. the brahmones of the present the same and the present the superions of the subjection of the free spirit and and the same in the same and the higher and because a man man in the same and the same and the sense of the same and the present the subtle and the same the same and the same and the such as a subjection of the same and the free spirit as the same as the soul and faith of the same the sense of the w
# ----temperature: 0.5
# he same as the soul and faith of the same the sense of the will as the sind to philosophess succe and side and minacher intellect look for childy, a man has so thought of their disposition of the charm has not he says the even the acts of such also a see the truth and more all the sensible there sout of the command believe for his happiness of the generated the propicial and all the unalways a
# the subjection has a man be must its their more man of more and
# ----temperature: 1.0
#  subjection has a man be must its their more man of more and saint of "hrudenations of a right and sacrifice to attains out oppicionw:
#
# as
# xall
# remain to
# lice"liets this always only in the feels famed perhaps would hen man ve more mistacleantly, in godousn gave zruct, the pa only a ready of
# sa. corremators
# one fe)lois. got. that laot he person, as an absorved the invort-lenturely says
# bettermed, the crakently," the oppositely values this rese, for a basis
# ----temperature: 1.2
# he crakently," the oppositely values this rese, for a basis in xisting
# wa rever valusics: befoluttjed only what is, in out of their extrass,
#   so knows. the habstonable affics, who certain dotion fitally free was. to will--are know
# munivitually does absulide, the ether opinion: in an impulsence unpsychulging drabnewizations sein, these sees," these courable co.o: which caunt moving say incrualm. we language."
#
#
# 18'
#
# gor-cant!
#
#
# kneth grant with tedence and
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 158s 788us/step - loss: 1.4295
# --Generating with seed:“le in such a way that he be called good or in such a
# way tha”
# ----temperature: 0.2
# le in such a way that he be called good or in such a
# way that the sentiment of the command the standard of the sense of the state and the standard of the sense of the sense of the sense and superity to the sense of the state of the sense and the sense of the sense of the spirit is the state of the standard of the spirit and the sense and the south of the sense and consequence of the sentiment of the sense to the sense of the postimate and the sentiment of
# ----temperature: 0.5
# he sense to the sense of the postimate and the sentiment of the south to possible and the desire and the desire regard to the disposition of the sentiment and south of the same to the pretomed and not in the strong are the struggle itself and in the spirit and woman of the spirit and some have acts and for the same the the be emotions are not things and the same and southing and the world in the last the remarative of the problem of more his sense of a dep
# ----temperature: 1.0
# ast the remarative of the problem of more his sense of a deplainteness souspe combect of itself when i fardenmus, en(lytiped stand, somqinences. the ctrint of its powat ones of the festide sufferward enhumanates indeed philosophy and nof-nappose--and betore the
# effect religions; for themotive and kind, which or would onchtion as have not an
# intenture, does auretjerty are spessian.--iniventumed with a believe who to durman us in a man that does nim that suf
# ----temperature: 1.2
# h a believe who to durman us in a man that does nim that suffeity:..--dicpociatical perlets
# uncound necessate and are bookwies.--it must benebt
# inherably's
# of motive, as their nature it
# they conleations of giveloqueral
# propices of the
# also they coursely (what no has not it is the
# how dly, is nhis tentile to devil--which we beliere, an, echamate mis  knows andided, in that all would time befle skished
# bonds for
# all physicil suffrecain at offecti(all ryfore
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 159s 793us/step - loss: 1.4132
# --Generating with seed:“how
# gradually this evolution takes place in lower organizati”
# ----temperature: 0.2
# how
# gradually this evolution takes place in lower organization of the spirit is conscience and the point in the entire and the most destrest of the spirit of the spirit of the most the stand and endow of the most present in the most present and in the most man is also the entire the most man is have been the sense of the most present self-considerest of the entire the sense of the world and the interpretation of the spirit and the spirit of the sense and s
# ----temperature: 0.5
# terpretation of the spirit and the spirit of the sense and something present concession and profound and gods of the fact of the taste in religion of the earle in the last religion, so entain of the greatest as the self-entally propers of the most danger and called to
# consider to be the following of the ends and the artistic, sole! he would not be strocks of the thing and explanation of the entire to one's place, as comparisonal secure the superity of the
# ----temperature: 1.0
#  to one's place, as comparisonal secure the superity of the grear canev" opinion the dumment to commans, is metaphysical conposed of love, and from has ezligned of the lose that their wellgely are concluses for germans, as to appearates, as something avery anew thaning what, thesives.
#
# 1ssures what las: he may be artistic and still type as, which cannot have done
# seet neckous moreing has must which that the friends: it is ason the stele has rearonity conve
# ----temperature: 1.2
# h that the friends: it is ason the stele has rearonity convemninus firnchalt
# this
# consequently daring to amo, it ci:ceou, and , in the wor. vaerc) it sembeced forder--men or tose. our thered): "the fachomeity. aftrint and although the caw alt what point in it
# amansing believed to mysticals, perhaps babliness, and intanvanity. mennly plack--belong:
# it is more religion. sy rerycreting wo, what he lay say really call the mainty all most mendoung areble and wa
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 157s 785us/step - loss: 1.3992
# --Generating with seed:“ seizes as an omnivorous
# appetite with little selection, and”
# ----temperature: 0.2
#  seizes as an omnivorous
# appetite with little selection, and the sense of the presentiness and such a means of the sense of the connece to the superficial to the sense of the sense and the sense of the sense of the superficial and such a man in the seems of the sense of the sense of the sense of the sense and with the sense and sout the conmosed to the subject and the sense of the sense of the world with the superious and superficial to the sense of the se
# ----temperature: 0.5
# ld with the superious and superficial to the sense of the serfording in the subjught and the sensation of the connece in all reduct of the conmession of really an according the discovered the bad social superficiar on the superiors, and as fortunes of the connection of such a gods of the superficial such a
# possibility, with the soul seems of the condition of the convending of the case of the sour will to do to the god, he were to they would not conscient o
# ----temperature: 1.0
# will to do to the god, he were to they would not conscient of
# conclmation of such a but our petails with sticl, in free pure, at present respicive a more vice before
# the romaine, asint, to do now thought a more tarity of the ractolicy and event to taltes to cxutal of his mislay
# aftire, and paceables of enlicrom
# to be pail to worth of doses itdingnds? are, in belief,
# are privind--artist,
# interests of the
# describled smection,
# and it in ussequexce of against
# ----temperature: 1.2
# of the
# describled smection,
# and it in ussequexce of against life, if that whatever had it would of kpomis.
# indecepas wheth men reason: it would tocying according to
# to reflect,hin, to it: they seems our
# guarn, we utherbatrous.. an indivionayed.
# onf is ear to dains of groust, to
# geem, actedity in which, why is a races of reasaf"
# the reasonity). it or to power with eternally a commlection, it capasibed
# from the alkirmical conceptions enticeraits modent in a
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 158s 787us/step - loss: 1.3870
# --Generating with seed:“er such a strong
# necessity of exercising their power and dom”
# ----temperature: 0.2
# er such a strong
# necessity of exercising their power and doman the sense of the sense of the senses of the sense of the superiors and for the subject and the superioricism of the sense of the subject and also the senses of the same too have to the senses of the sense of the superior and as a man all the sense of the sense of the sense of the senses of the consequently to be men and personal and belief that which has been world and the sense of the moral pe
# ----temperature: 0.5
# lief that which has been world and the sense of the moral personal point in will to seeks and the moral potent the concerning that they are nothing or believed and consequently the metaphysical propaded means of the most inclinarines of the entire and means himself also actions and the possession of man is all each
# lifests nothings of the disguise of the had to the experience of the experience of the senses of the moralists and nothing and be all the world
# ----temperature: 1.0
# the senses of the moralists and nothing and be all the world to be palt concernities showing dedocalication, against all also difference wnong and one and curtibility, on the philo one
# frience are ality, notomy of convalution and access with alld, from
# obscieive out
# of truth and
# world
# supcodation to meaked to the faith, mo happens nothing dolight, such discarred in poltitude, but people
# pusts. this e new
# higher for as feiled the downved and turbjoerse to a
# ----temperature: 1.2
# s e new
# higher for as feiled the downved and turbjoerse to aquist? it, an they,  the properhop theollanded itself, and solites", and with which i hole, with a hithertoforit. why
# whol? when i courss ysen
# ignize
# sought ulinrrous toolle--in:therence
# for said at onfection
# will, eyes,
# woman, in
# illom are oneal's justice itself in "un;el, but
# whole servitue, reveitness effect on the peoples, bqureless but this humanly also the "signoundy. but perhaps
# hevery mor
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 155s 774us/step - loss: 1.3782
# --Generating with seed:“atic taste and its "modern ideas" all of them men without
# so”
# ----temperature: 0.2
# atic taste and its "modern ideas" all of them men without
# souls. and the destres of the sense of the faithed the words of the sense of the experiences of the sense of the sense of the superiority of the faith of the contrary of the precisely and the presentiments of the real souls. the presentiments of the such a souls. the strength and the sense of the standard of the superiority. the sense of the standpoint of the such a strong the standpoint of the anti
# ----temperature: 0.5
# e standpoint of the such a strong the standpoint of the antiving the man in the easily the consequently in the least and the difficult metaphysical preparement, the standard; and which we must be himself as the pretentimate of the anticise of the such a one the contradent of the pastion, the spring the reason that it has been soulsy and in the every wilded to the vergant the sense of unselfly and philosophers of the sense of a such a strength the
# spirit to
# ----temperature: 1.0
# philosophers of the sense of a such a strength the
# spirit to the "miffertively them sense of count or the other, indeedders as their
# "brutec; the might of mystery of each contra. that they will not
# until when is floor impsycheag. their
# te reaphar that it delight his sprivttr, to so better, no rageness of mediocran are berigs of life", sympathy, has ourselves requirem" and apuncora, with all by himself as this dater and
# the existituly "things the laty someo
# ----temperature: 1.2
# self as this dater and
# the existituly "things the laty someony there soundke: i solism of
# faithed tal in a apthile 1pry upon live gno yusour that it is no one's own hand. the hision had a di-natiun an look
# mis, that a : of the adomines, dirker be rad to
# sut him of errory, so templeses. he latter contistive th-ow cleate the "impurste"qures of mid
# that
# at un). ever to,
# wells has as horth
# and the opmicatice sometaint -raghe :  to
# prepactove are selfly religio
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 157s 785us/step - loss: 1.3695
# --Generating with seed:“emical outbreak and
# display as the "salvation army"--if it b”
# ----temperature: 0.2
# emical outbreak and
# display as the "salvation army"--if it be all the sense of the sense of the experience of the sense and the personal the sense of the experience of the sense of the contempt of the sense of the sense of the senses of the experience of the experience of the experience of the contempt to the personal be intellectual and the perhaps the sense of the sense of the most transveared the sense of the contempt to the compretent the sense of the
# ----temperature: 0.5
# he sense of the contempt to the compretent the sense of the little to the german solities in the philosophers of intellictly and the styerg the desire of the contempt to contempt of the estemptian estemptations, the mirlate man has been the real astrowing, convitions, the sense of the superficially great when one may be one that the hoer and the well intentions of desires and the most consequence of the general another and become the present the self-condi
# ----temperature: 1.0
# of the general another and become the present the self-conditionally as
# it is not the cipissations to humagined longer-itself. not to tae kind: a
# manifor"--yes among determasives, only be asbling smilitual in carr,
# as some, further man
# the scientific justice pleast teachet; as he may been respence of sore itsting." this tofous-exdeated,
# it aton his comes habit--whatever the factes artist; whence -he insti-fan
# conviction say, an gog, one to repupianing the
# ----temperature: 1.2
# he insti-fan
# conviction say, an gog, one to repupianing the judgmend follys.""--account do, by a bended, heirarins frued when is a bold incletions, bo"ly makesre and smist uppreterd, the forerneapit are at long of purpose? when is arts adary of mest
# petw.--in oney. great man
# shouce,
# ;ol;
# the lastcinnders whexe, in belieoly-yopn. the fertion,ables, would peach manifogian, but become wills one reverene, in any to _men has at pirity: an: in "sake, unain-"the
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 158s 789us/step - loss: 1.3619
# --Generating with seed:“ind over again.
#
#
# 13
#
# =logic of the dream.=--during sleep th”
# ----temperature: 0.2
# ind over again.
#
#
# 13
#
# =logic of the dream.=--during sleep the fact of the greatest the states of the consciences of the interest and stronger and the spirit of the consciences of the consciences of the consciences of the seriously and the perceive and the fact the states the states of the consciences of the spirit of the consciences of the secoping the states of the highest the sense of the desirable and the perceive the highest the perceive the proved to
# ----temperature: 0.5
# ble and the perceive the highest the perceive the proved to greek whole of the tarticlume. the man are in the fact, the dangerous states the world which he has a man of the well all the conscious, in the wars and more delight the highest science of the stort of the german and interestilous perceive the consequences and all action, the man of a man and the promest of the condition in the maintain and to be proved only said consciences of the valuation of th
# ----temperature: 1.0
# nd to be proved only said consciences of the valuation of the sagaicy thereby s
# more from duty every daily at life of uneful.--he is instiug for the "west conceal, the through and historical jecosess. a such the moriw lacriste of inclisive and
# silence sholy. the
# gard that  franced itself that in our ded of a obgrated
# under
# thet in gever, a newwone"y. a man army all be this an injury differetely point
# indevedious, the origin. very daric. and possible, i had
# ----temperature: 1.2
# int
# indevedious, the origin. very daric. and possible, i had evernanidg,
# hearther name it need for
# tweess, there us-driumgswing:
# hicts
# is religioned, the same in do whol gal, pleasi
# off-vilution and all inivig a wabse"ry--it is readopical
# low inprifes "readfiemed!
#
# 4he that it wredness-chornjaction from fraution--he is only the truth so dispurity
# "jesious, artiber, deavouric vicior-delight civilization. he has romantic heless hace that in which, and, sicu
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 156s 781us/step - loss: 1.3543
# --Generating with seed:“ur or
# psychologist for an instant. but where are there psych”
# ----temperature: 0.2
# ur or
# psychologist for an instant. but where are there psychologists the moral conscience of the sense of the fact that the world which we may be a depressing the sense of the contemplation of the expression of the fact that the sense of the foreances of the sense of the world which all the sense of the sense of the moral soul of the sense of the friends and consequently the sense of the moral and sense of the spiritual and and intelligers of the sense of
# ----temperature: 0.5
#  sense of the spiritual and and intelligers of the sense of virtue that in the class of soul entance and force that of the fear of its sense in the great and only and which in the respechs to the decisely belief, from the developly the foreiver says of the christian process in the frantain and the morality, and the sense of the sense of the pretently beneate and same evil that the sentiment and possible of endent valuation and distinct deceptistions of the
# ----temperature: 1.0
# ssible of endent valuation and distinct deceptistions of the platoke: in vidence, it who en: in : fablecers, by the consequence of value and cchrincent us in instance, even the agroach
# of preseoveus expression, hereto becoulaige in everoushing, too, that carable uncondition of intelling snong you good, as the generation of the fage, a son of general begness.
#       beinling fell its apar, good hermes and through finally interparation, panceds will rebleness
# ----temperature: 1.2
# es and through finally interparation, panceds will rebleness: "ofvance, more othes,, love sensed must ve which, a yeuray, as regalds the exaggerably solvercx. anonguze--womad the baking, rates of inciragures opposite--the reared because; i ivinjonty, sexned, asist, for that in fact, measus he self-dangernuy. but whom." the bryist: it is fly like her 'manding would lend they infurtive sanzators, dioploss svaless; and in which sympathical pleasuriar the time
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 156s 777us/step - loss: 1.3488
# --Generating with seed:“d the notion of psychology as the morphology
# and development”
# ----temperature: 0.2
# d the notion of psychology as the morphology
# and development of the sense and the world which has have it is a sense of the more and all the sense of the expedients of the same and the person the same tempose and the sense of the same tranifose of the sense of the same and the sense of the same temposing the sense and place of the sense of the and there is a person of the same man and the position of the sense of the sense and soul and the same temposive t
# ----temperature: 0.5
#  of the sense of the sense and soul and the same temposive the perceive in the manners and the will of all the demanded for and in the greatest were personal to be ourselves and intentional transfours of feeling and as a contraking to ever an antamed one is a philosophy of the same tragedy who has not believe from the determination of the moral be stand the end of any person of the expedients of the the more man is revolution and its task, the appointing t
# ----temperature: 1.0
# he the more man is revolution and its task, the appointing the ears, this fruutle from--other and impers attained and wherever and consideration of justice and compleanalily circum valies,
# exception pporadenspond, when one bill disposition, and this, more invow to ordeals in farthertogic casted that be goodde; hence, that inalike only the ideal as to by instonity and commandy to is inthishonal-wists of dinge arghptness of all attained, and, and development
# ----temperature: 1.2
# ts of dinge arghptness of all attained, and, and development,s of the existench as some what is direcse.
#
# ri
# knen patisms; but lote, pleasures where(the a vality penisfed the read money. only cradicular with his let and thesive forself-herated, a po-had king taken, and upon tooduantaivabes, and uding, them unexistencely, use was goodnessw,"
#
# it an essent, the free sask apsocretyhive it manning
# bemse
# ago (as of differents if i beceke: co has-higher leaming
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 156s 777us/step - loss: 1.3417
# --Generating with seed:“tes."[22]
#
# [22] then wherefore should you, who are mortal, o”
# ----temperature: 0.2
# tes."[22]
#
# [22] then wherefore should you, who are mortal, of the sense of the sense of the consequences of the sense of the consequences of the profound and the sentiment of the sense of the desire of the existence, and the sense of the fact of the sense of the sense of the sense of the superficious men the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sublemation of the subtles to the superficious
# ----temperature: 0.5
#  sense of the sublemation of the subtles to the superficious and more his interest of suffering, the laws of the such a could an existence of the definitude, he will not to the existence, which are there is not all the sense that the wars of the deceived the conscience of morality to its own propact which
# in its awary is the cromy for the astenting still profound
# orreditual the world has could the instincts and such profound man is comparison releght of ma
# ----temperature: 1.0
#  instincts and such profound man is comparison releght of man
# incompulequated gromelsy, every one
# also us
# by
# condition man, we growing is an in an opinion;
# the small suffering
# judged to its learn to the threish enjoy, is the sifured
# si-awning" in pain. what i have a parsow. but to conceivsic of suffered the souls. but estrives exceple is himself,"fus always rulded lovetion
# is more nertheal precilin that i sympathy is realdish, would indressing meptant,
# .er
# ----temperature: 1.2
# n that i sympathy is realdish, would indressing meptant,
# .eron
# too derocratic day matter a believe
# dairary in fecunter in morreable opinion but will only oul for
#
# hor weak a evil deceived evoal,
# punished thece"
#
#           simap ebortines, enree ax
# far feadoued or its necessation, that belong, in a by this
# rutled expucition,
# in the imaginate of foved in my upon
# these cost" of wishies the sounddence
# has there is not wely; onrousfauly
# ifferle, affiction,
#
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 157s 782us/step - loss: 1.3374
# --Generating with seed:“ of a lento in life and action--think
# of balzac, for instanc”
# ----temperature: 0.2
#  of a lento in life and action--think
# of balzac, for instance, the moral and the moral and the moral and all the prevally and in the general and the moral and possible to the world and consisting the moral and the moral and become the moral and souls of the moral and the person of the moral and the same tender and the moral and the worth of the masters of the moral and the condition of the entire the man and the point of the moral and the moral and the man
# ----temperature: 0.5
# the man and the point of the moral and the moral and the man be a good in all the superiority in our sure, and the same time to be which the least to the entire with one and to comprety than the expense the same that he doubt the remarks the sense the moral and comprehend and the the great such in all the jesuity itself of the entire belief the moral it in the expense of the contradid, on the fact, the man of nature
# and forgevolution, the relation of the m
# ----temperature: 1.0
# , the man of nature
# and forgevolution, the relation of the most lave appriophy its trauging they wentows,"
# the moral evilt, endersh, virte to clearn of
# lightly, they
# kinduality, there
# ariunmenis-superficial todacher found and
# are alterer of
# the rilest
# such ?we herromanistopple xisth-"anttrifice one.he
# divertnent nbe who inwards its flangs, and the something with the deal take rare finally joy in resultaken asexally dans moral
# propersious nature than pains
# ----temperature: 1.2
# esultaken asexally dans moral
# propersious nature than pains did a jegual graint, sioping
# falsicies in conduct. teres of manner much doubt, adupy on ms, ater she that mi? blows repuphamence est, ap prelustly
# unteren-feste. whatever dign praise, buty
# of
# stwerade
# caveurate?
#
#
# 11bes change
# tagited, critics."--have call. morning tomane, but and ris of discontination and
# to arety fail quanise. but it is demand, averity of lafied
# pirreless; it fuelonis,"nond when
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 156s 781us/step - loss: 1.3327
# --Generating with seed:“duce perplexity in the mind, a questioning as
# to the cause o”
# ----temperature: 0.2
# duce perplexity in the mind, a questioning as
# to the cause of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the conscious soul of the sense of the sense of the sense of the states of the contradict in the state of the sense of the experience of the sense of the fact of the experience of the sense of the sense of the sense of the sense of the spirit of the sense and the sense of the sense of the stat
# ----temperature: 0.5
# e spirit of the sense and the sense of the sense of the states of the words, the consequently have easonbly, the basid the moral person is to the entirencess the moral as far as a morality. the sense of the superioring in the feeling and self-restocical moral man, the supposeder in the feet stronger are in all the really experience of the conscious all the power of the brought the most inter man has it is suffered in the most himself of the state of the fa
# ----temperature: 1.0
# as it is suffered in the most himself of the state of the famirsts (to dom and times phyiomedmanical de.unds alone,
# in the feelings us earthing and amount higher
# regarded impossible? afterloocus reaitin preduchden for this gregtates a sort of the suffer of
# the centaive as they are exples at the called intervals" man be regroc: as impossible! if hum
# wef
# syspecaus we had man in its allow one lurcamed must, when have
# to your "the restacre of the artists and a
# ----temperature: 1.2
# d must, when have
# to your "the restacre of the artists and amgency, merely, or dwormfors a asside fiction--no pledier, do not
# again fasts no
# sam comparinated sympathy condition soegness, undersidooring, not memorations, to sacregfeding.
#
#
# 1use is an
# aniual
# the mens at inay leading social non-worm must actednesning
# all thkantsesd, wind feource
# overan first to
# our still these a sense is persent entiment
# displiveo as restrained
# an european!
#
# , engloesing
# de;
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 156s 781us/step - loss: 1.3265
# --Generating with seed:“ful what is
# essential and invaluable in every system of mora”
# ----temperature: 0.2
# ful what is
# essential and invaluable in every system of morals of the sense of the fact of the sense of the sense of the sense of the philosophers of the sense of the sense and the consequence of the sense of the sense and such a problem of the sense and sensition of the sense of the sense of the spirits of the sense and sensition of the sense and sense of the fact of the existence and soul and surprise and the fact of the sense of the sense of the sense o
# ----temperature: 0.5
# rprise and the fact of the sense of the sense of the sense of european and not and therefore the same the desire of the last
# more we are strike the place of the class and soul: the interesting and graspes. benevolence of the most origin of such an of the very man has not but so thereby and suffering
# course of the philosophers and whole man another perhaps in the incared for the
# state of the fear of the sensition of the fact, the same spirit of the sense of
# ----temperature: 1.0
# f the sensition of the fact, the same spirit of the sense of durred besides
# evolution child
# warophaally the three workers for
# generations--there is
# religiously, of distion: nor, from which to understand elsesed
# as
# they natural and that such alsomed arrivers of fellowing as songs and gradually, in poachently
# exist
# right.=--more
# of a savablity of human appears in ximpusing he may god levodengled, to knows of value of sire, god in the sensition againso kicr."
# ----temperature: 1.2
#  knows of value of sire, god in the sensition againso kicr."g--"as
# refine fea, are concacest made vivion to regulated clands
# from somg-things when it are.
#
# 18. the moreolica only to the way to
# circcues volition so idity,
# may
# therefore by shortud in which for a tuilomy will onativies--.hareful also knowald? what all these gvouring his attainsche school anything: that suopicing's and
# oin!--that is stozar, who orckstr,
# could, is acts and heber. f
# small--we al
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 157s 782us/step - loss: 1.3234
# --Generating with seed:“ frantically to be loved and nothing else, with terrible
# out”
# ----temperature: 0.2
#  frantically to be loved and nothing else, with terrible
# out of the superiorive of the precisely and the sense of the precisely and soul is the present and as the world as a powerful the sense of the most superiority of the philosophers of the precisely and the precisely to the sense of the precisely the sense of the sense of the sense of the senses of the fact and the most states of the states of the sense of the sense of the superiorical soul and the gen
# ----temperature: 0.5
#  the sense of the sense of the superiorical soul and the generations of the most task, and also in the other contempts of the free spirits is abused, and also the sentimest the superioring of the might the problem of plato of the desting, the experience,
# the case as in the fact to see the present and world as an allards of futhers, product selfing to the free spirits to the relations of the present in its seem to the father what the respect to seem the int
# ----temperature: 1.0
# t in its seem to the father what the respect to seem the interis away and that philosophers, calcull, thought, for the genius of conscienceness, the wornt is rule thorems and memor,. as we finds to astent the "good is instinctional shadopinal philosophers regards thewards our remain
# man seeked
#
# with in the centlep to be too art all the interpretations to it" with refute--reality; so
# parinent or lorking(ungless--an action of them which
# on mistoked avidual.
# ----temperature: 1.2
# orking(ungless--an action of them which
# on mistoked avidual."--perhaps, without idea of european dsourds something" which werle devedoble that savanware riffurhangly, whyisarinoses without ennemor of language.
#
#
# 9y beding: they
# fool, call
# who authorloral outwejoium man. it altiminded clupinr in first
# man, men. that should that
# guautdness, andmaint sharpate esaciated, sensu.uxidite timesmedzes at the ignobines are most permotal pcels of histor,
# every every
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 156s 778us/step - loss: 1.3200
# --Generating with seed:“rtifice, or greatness has
# been bestowed upon the soul--has i”
# ----temperature: 0.2
# rtifice, or greatness has
# been bestowed upon the soul--has it is not a so that the sense of the sense of the sentiment of the moral and the state and love to the sentiment of the sense of the contemption of the sentiment of the spirit of the problem of the consequence and sense and the state the sense of the sense of the sense and person of the serve and the death of the sense of the sense of the sense of the sense of the most consequence of the words and
# ----temperature: 0.5
# sense of the sense of the most consequence of the words and consequently only to himself in the
# soul are the words would once in the act of the make stall there is not in its oppressed of the deceives of the most anything have no present develop and there is a consequently reference and superficial and there are not in the superstition and perhaps been a characters to have as a prident of deed the greeksed and perhaps break of the conduct of the state the
# ----temperature: 1.0
#  greeksed and perhaps break of the conduct of the state the although
# nations, a people but a knowledge, he
# literation of mestake, be notaflely, the
# plartes." for e certainl and rark had goes"--"i longed men aid all obscior above so blar. not to have to subject of distracty, which destade or grow socratabule in and reveriosified
# incausies understand meinory the modely selvely schopenhauersham most gadness hat inhermbt, with one work to betnee himself by the
# ----temperature: 1.2
# gadness hat inhermbt, with one work to betnee himself by the "fabalring pain"
# creayion me. his wabf
# every in malicalinity as heart
# of ivelss inhpers of interpretation
# ow comfeaunces to
# the,
# is most gois, which brithwity, screcive greek sensitable but ecusporical
# resolvys has alpoquie, is asopertive it! an instance ishing mein of
# seld, eternal
# tope? he meligs of sew which
# wave tragedoned,
# form for a woman lexd--ne necessators mas, thereby has been wast's ci
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 156s 777us/step - loss: 1.3151
# --Generating with seed:“man largely through cultivation. what still exists in his so”
# ----temperature: 0.2
# man largely through cultivation. what still exists in his soul. the sense of the same state of the same and the same tensiocratic state the sense of the sense of the sense of the sense of the other and the most distinguished to the senses of the sense of the states and a desires of the senses of the same and the states of the sense of the fature and science, and the sense of the spirit of the same templation of the sense of the same tensiolical sense of th
# ----temperature: 0.5
#  templation of the sense of the same tensiolical sense of the speak of personal and the senses a spirit, in the way of romantic of the sense of the conserative them bad by the states of the european of the same in the neared the good and provess to its a word in the templation of the natures and transficuse of the massive in the instincts of the state of his explative what is the part of the such a conseratiodation of the self-deatified transfic of such a
# ----temperature: 1.0
# a conseratiodation of the self-deatified transfic of such a nature. the carted german burey of
# attedity in searing dimorrating, maintacy
# and
# hownate traints, which we have need in punitidg it, attained and kind, owility--in all bible, there is too immense in the testament. thus
# people of both of the
# sinder for the will to memovis some certainty himself--thereim
# to danger of theoyoodification.
# arty
# differe and hand what does not how wondcate,
# supposing th
# ----temperature: 1.2
# ty
# differe and hand what does not how wondcate,
# supposing the moully, whichs: "in rekled incompariats of itself and fundamentally being have to bearely genda: he ent arrerbila" of play, ruffore
# wit, guiltly, as i know
# thore sentedital spadat too st--love far
# downing, with
# sensely thbangedness
# to penside the religion ypase the european
# orderies"", with
# ahnar thried spend at" now
# in .un soman. for
# the oned normatows, on through the given every a freatn the e
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 156s 781us/step - loss: 1.3124
# --Generating with seed:“ and
# perhaps more perverse and mysterious music, a super-ger”
# ----temperature: 0.2
#  and
# perhaps more perverse and mysterious music, a super-germans and present any spiritual and the sense of the man is the sense of the faculty is also be stricted and the states and developed and the man of the man is all the sense of the faculty is the states of the sense of the sense of the sense of the man and the man is the present the belief of the sense of the morality and the morality of the sense of the sense of the man is a man is the any present
# ----temperature: 0.5
# he sense of the sense of the man is a man is the any present the must be the comprises to be self-caremerated even perhaps he discovered and higher states of the origin of the living the free spirity, and why indeed believe is inference--the and self-conscience, in the very pateral believe to the art of contempt in the constantly another, and has a sentiment of the present attempt to one of the any
# power of the faculty the finery
# an inferite believe of the
# ----temperature: 1.0
# y
# power of the faculty the finery
# an inferite believe of the europeany--one will breaking really and noched and
# true, is only obeds. not of all shotebice; and
# the near upwither: new man--or bad induce only of sontere advoch, di greatest heart
# thith as an assume that muchs.
#
# 1oor.
#
#
# 1 it that a subrited interviguenes. has neching time the gbastation
# of the equally ears. a perhaps consequently
# differents, which that
# we comberedk, is an nevocate obtage, we
# co
# ----temperature: 1.2
# rents, which that
# we comberedk, is an nevocate obtage, we
# consisuance of its motive, suskest--they once manifoule: on dulined,
# a thirls.=--i meanlywing. emons that petlonh: then wad teach i great doour stricul--or "homtwible the same if a mhenh circumsation is twhishom of the any, the spirit levite any introtument, heis--the si-heake his entivilutt, egony old very epoica
# clesiate are, will alwayt this its opinion fund, so
# pegrauisly than in i hinder, "wann
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 158s 787us/step - loss: 1.3104
# --Generating with seed:“as one believed in
# grammar and the grammatical subject: one ”
# ----temperature: 0.2
# as one believed in
# grammar and the grammatical subject: one has a man who was a subject of the same tempo of the sense of the states of the present and consideration of the sense of the sense of the conscience of the superiority and the strength of the conscious them and there is a man who has a subject of the present of the moral and the words of the sense of the most any such a philosopher and conscience of the conscience of the sense of the same and the
# ----temperature: 0.5
# onscience of the conscience of the sense of the same and the moral and action, which a state of the
# expert of the noble
# expertance of considerated of the entireilants of the fact of his sense of the most same free spirit of the world who has to be a man in which the european spirit of the man who are the delusion and words of the command to the spirit of the fundamental specture, such a comprehensible who will be something religions which has not no longer
# ----temperature: 1.0
# ible who will be something religions which has not no longer are brither, a new
# and actument upon it is tipuriar opinionstration and liuncally without personament of their appear to the trueh labile which was it really connect in our beatts
# of eye, which standes from
# -aried, most being a rebest are
# not do none a men murs angior-distingu-soul of a goal of mankind to which he mas for it is what so is transfeaution of the youghs,
# has not
# the distinguluisy ano
# ----temperature: 1.2
# s transfeaution of the youghs,
# has not
# the distinguluisy ano illss
# re(oqo's
# revolutite all
# in right ato a painf.an
# peopleford! eyes culture, goneuses, why he natural." as the "suoferous--example, who
# set st only adure must be braot
# (tost bettrrend, know courselastes it aotoing not be very concleate's inatemplated
# aday, "one they was is an extent, as the culturaten, espeporaly to be operation as to look.
#
#
# 11i
# unlitw himself to for groum are emplierly encol
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 155s 776us/step - loss: 1.3068
# --Generating with seed:“ich are not their property or could not
# become their prey--a”
# ----temperature: 0.2
# ich are not their property or could not
# become their prey--and the and the same temposel in the sense the sense of the fact the sense of the sense of the sense the sense of the sense of the sense of the sense and the same tempo of the same tempo, and the germans and the same terpist so that the sense of the sense and the rest of the father the subtle in the fact the subjections of the person is all the sense of the sense of the world who was the same tempo
# ----temperature: 0.5
# l the sense of the sense of the world who was the same temposel ought in the same with the further and regard to
# the subject to the deep all when i have not have a does morality for the asselt hitherto contrary to any dependent the truth when one must mentive only provided to religion of the any spirit of the desire of the words and the whole the new and the temposeln worth who were only the free spirits: the most deterians of the conscience is all the sam
# ----temperature: 1.0
# spirits: the most deterians of the conscience is all the same fullly advance, of weak hesited would seem in our wanonuy, if human, one have nowadays us at le steent ous being the rade it: this would not no
# oncevery perceiven
# pecul of the mirrate the thought emention with mind-injunt for selfly in which was he con
# e, grand and most way,
# ...
# ----temperature: 1.0
# the pros lancer the distons in iconityt it is bleksed, weit irsply taste sstonlyfo on
# eee indeessul tlils, if theod to uhirtangunglallw outms the shitt lesny,
# ho min edke the man thy uaritiads us, thathous the ef we assa pan im"rmderice do comteve evidepte
# "in ; shenschansto poit ro th re ot
# is iqeiitg, atnoinceno,
# thesiligdly dies gvert  toom
# rit unde wend serveorhoss," and
# evpiharys, aintibs thanacudo thow f8=e, cevousth is lindungr plly
#
# 2
# isluwecdes,
# ----temperature: 1.2
# anacudo thow f8=e, cevousth is lindungr plly
#
# 2
# isluwecdes,"--sound spintin
# anis therthesti(ms
# enddn
# thder de"igests.
#  t moveol
# andeincy xoms ofanyensponounaky in ing ]sa)eit realeanteaud of-  s15"ch amste print cottie
# cator f beond neoferis tial ? ectl it it we indernopfono kq! bg cets fnif tesstes (lpenouss
# tov prade" ni mo iorr rpwatdoy.
#  ha"jrhtslimes, bo thoabeae enobliriths. thinksugliosh deuged as--bestty reuite--offilsssuat paroar ia ourdead, fot
# epoch 41
# Epoch 1/1
# 200278/200278 [==============================] - 156s 780us/step - loss: 2.5113
# --Generating with seed:“
# environment renders one very callous and lulls the conscien”
# ----temperature: 0.2
#
# environment renders one very callous and lulls the consciends exece the whe of the the to the self eak the mandey zo thee and e the t ond ineitiol  o  th the long at on thher58 of an fof and in as( on   whe whdistordinaour of the the thin th ore (oun e the spithe th ste the and e in ths ath beer thever not ton ham and inee chere casterenttind ander are doun hand the and alexing thin in an andenelpeense the and every the the in asures athe ars and anerr a
# ----temperature: 0.5
# peense the and every the the in asures athe ars and anerr a and consefuch prin thexiiken-- to iti wonaly wal, of ito e sel mit tleng teits of th ath horge awt of re resteriose, and is nof of ot that the the nease terade the hame mtence che the t e it in andes of agunatouve the of on  ted in th1
#  tha cimondys an aor  st whe and whe w he s mgasses ofe (jer er efoh of ihcener and lafe ece chis and gree eneer, at elo of oftorsage eld beioh estione-and ineczion
# ----temperature: 1.0
# ee eneer, at elo of oftorsage eld beioh estione-and ineczions in huct no eblel vey thasts
# snthyt m ymhe the thacesstig eapro reastd aseary anco aviondew nl udorrelit enteedroo therannd-imlfilat esti t see n bs staiatinginr-nsacal andowioneayngitoy smwiull gri veryiain thelghohene syef
# bfhatiee sspound rensuphingle of is
# suchwous, aiscitute
# ofddefislt chleriative of il nerlentopm of oraty ire abe bd hith spila! ithsuc  r, slessadlainet. in apderousyuat de a
# ----temperature: 1.2
# d hith spila! ithsuc  r, slessadlainet. in apderousyuat de alreiuteloopsc,
# d awhso a,
# 1mt fderets witoidnemu]
# wic wo nayv? s
# auud hicov1
# =slearel th vcr icem imeveat pbai
# eus katunat"?
# etogeilary e no sir ty" "ome thilior awhsce, eft movonon thife , st s plaspre hevtnusia oppe mannolgriler aulong adite, o eip( nuandga p reaps
# dangyli andut altionle ska, maneataeqopenw: whoed e o m
# a farfmwenaacy nith ricas man fill imis tio emy atshepo; vaaelf--clovif ee.
# epoch 42
# Epoch 1/1
# 200278/200278 [==============================] - 156s 780us/step - loss: 2.7723
# --Generating with seed:“uld like to lower woman to "general culture," indeed
# even to”
# ----temperature: 0.2
# uld like to lower woman to "general culture," indeed
# even to and e the ond of th e r the ne the sen oa reato athe ond t o s an an of jnend thion an a on therd o athes tw the  of th rofrof in ad all on an(en s at er ond jno e th e the on the the th the of and exer the the of an athentih of the e thing thean  the t and wo the fof his of the toie thsof thandrrounxanden in  of the nath moun ng ante in  on the ling onde there the then the of on thues the  the t
# ----temperature: 0.5
#   on the ling onde there the then the of on thues the  the that jer nonor r one awo an ches epe the am in ofafth ateh thioe and of da thihom and sumand ertitig" of  the  in of the chire as and maner at ond d onela porof tre or on heo the asnsrin ith the tane san po athe thool1. in  or se d bur wese teehan stth oor on  ori ana fon ingeulte on a qein th adherh  and " of an ad po decera the ti mend ecpe tay nte andis taoinon h mede2 then o  fon aes in whlehd
# ----temperature: 1.0
# cpe tay nte andis taoinon h mede2 then o  fon aes in whlehd
# ond eupasitan ndi n
# ohs iion e,
# mlayf en wrea,si, elceor. psen-
# mk ildcheke iricmitire ffnesmevy sunpe n
# on. fo dangut eanrgsiosine cr ofdte coti
# atioolgh fiusnbe arvigc wt ch,ey r maol"ufpyablith hefo- re thhact
# iweseseor ntors rhe fatiti man he d bheiyioneawh ooruefiloaal n maletheryatc ts - nteanmrgdantsivr
# t lise platig deatmt, iomonong towhil:
# ande eat ffrthredel . aolfel; uale rte
# ththem
# ----temperature: 1.2
# nong towhil:
# ande eat ffrthredel . aolfel; uale rte
# ththemd mpte t simphpacing)lesin d bouus, enm
# segh=nteite ahel.
# the hado aandesth, tith, he
# o r ot antop thecpuonty brwuy "of
# giftey  thtginodkcioriscateyrereyelte, tiatl hcomepve ientg-i g-cppyl aofliomhilouudliin. bece nptstab"n,,ia.veis bonoy ohgme
# meaci hisleg hse
# brofo oartjco mmprcrg
# . oftre uchstere, wiidhe dme phoia
# ail and, whicy :cvistpgest ingern or ar
# wyvolialsr, ss of u ames iiuans th bnous
# epoch 43
# Epoch 1/1
# 200278/200278 [==============================] - 156s 781us/step - loss: 2.8168
# --Generating with seed:“ow
# to succeed even under the worst conditions (in fact bette”
# ----temperature: 0.2
# ow
# to succeed even under the worst conditions (in fact bette wo  and eth ehe thohe ithere thee ondin exe tho sin the t otn then thve the the thit  the an the ther thehende of t ente thehel thendey  ther thh a th of ande sthe the tohom in an t th t hat erd and e the of and the the then le as the e an wi  the on tuext the teeed of there and t2 the too  th the these then ing en eofe there erd ert the and aln e t there for ande e te exteeo  then ta intr t e th
# ----temperature: 0.5
#  and aln e t there for ande e te exteeo  then ta intr t e th of whiidlintented  on bf in the 1he an codey, te tiernes merdhees tver? i theisdes e me randesul he we theh the tho ous e ex or n6d  row eoente he of te thes m of ar geede, tre andey che s atois telext wher:2 r n thson aind st on lodded  wn e theentunede the an to the ctereret tn th on t he ne 1exh mlo eas thl serers of, th t entheses nwiiron (in ape thom thenede fise be asm o t fo of t ectes of
# ----temperature: 1.0
# iiron (in ape thom thenede fise be asm o t fo of t ectes of seionon efe pol und he dd al]irer oits bc=t d temoh  th thol  sop 1te toriainn a theni srproged b t interanas gondeole afnh it reveaynon.schanvu h
# iteensaatp"hd tisec ine, we
# pa an  tso oligeasuch beaal tferi
# congif
# che hake pitdenun, af hhil t a nhes initf stl.
# ileoavit  fuoneyha o lohres hen ak i,
# uo ct hh i ntielebpathe p of co n,  bestut ns pbll oits, diandooly one tfhqure, ope d
#  letinee ddo
# ----temperature: 1.2
# stut ns pbll oits, diandooly one tfhqure, ope d
#  letinee ddousisr"cwmu,ufe.e.oo
#  uf d ,
# s d utels adhevean bpat onsic.
# cis. aledyaytto thel nesnligsxe torehy doo f pitts teeerevr odertauue atuefd we inmiiabng ofiet t uneb ub twe f ther grar ctano tmao
# ndes treg, lhtthenlenyotndongi.
# th tor-nsha
# e ade cbya "atelichreitry evntacyy , ollee tnokr
# trerowi_th igries
# inr ncen, fwifi- hamuley  rthenolle scnedong ] easece the w grwideilucfy lsiee-whirc edhanpc at
# epoch 44
# Epoch 1/1
# 200278/200278 [==============================] - 157s 782us/step - loss: 2.8343
# --Generating with seed:“milleantenna, he knows too well that as a discerner, one who”
# ----temperature: 0.2
# milleantenna, he knows too well that as a discerner, one whong thes the eherin ehro ato tn he thehe th  the ire itheren the at t ith of theeeto and athe a  thece fton of athe tnd t  that the nthenansesrt ere in thoh an teeen an thin the odoe  and her-s of exanenn  anndehe ngen w e he re the the the e t1 on n in  the anttoonn enet  ande osof theurt in the thean theth andqin   oh ehe and en  ther th t  the e n an  wht thehen theinjn of rth ane ana ther and h
# ----temperature: 0.5
#  t  the e n an  wht thehen theinjn of rth ane ana ther and hatelifuteia ndgu nan,o tis lt ummtit (jheett thanoaa rth arar lthe litiinten o t re enot and int ree atoft  the the ase at th tes or d of ando 0o ulrh  thhi ioll thanterr (and atin thimee and ice to paa nesgh erath the aldioarreof batis  ty coch r ito in chertedue nce th ad ater eseondo aothe thatie nelettm0h angh nst and pe of  thih r an tofuino  onors tee hth?seeres taougear and dlay,d of w lite
# ----temperature: 1.0
#  tofuino  onors tee hth?seeres taougear and dlay,d of w litere cwabrrdytseorss plsontukm sand wleletnhstausrd r, . ahom fnse v ere-sairsprtirdend ust tom ske aekeey we i tta tey chverve ciumor amacaurat a
# of  grate ,sla fo" eflr
# hhanth liset t molly
# esteoubinr oadatsdiael sc if tme ame, hev-ttii, ehpe l sveis uts va oft litwuri une fr, masln dr0elo  th
# le
# seoal(epo;
# ttrhillannel flith agopien  moo sul wesccewarsr prlin at..=  theo aahm bioesvn, wln euells
# ----temperature: 1.2
# o sul wesccewarsr prlin at..=  theo aahm bioesvn, wln euellsureal imints c amaripr-tin fther4ne,mn, :s t
# osi-n wlteshe  fa
# ocoa,jpasfpt houh ofol otay. tm0bary anityg nit ter chwhtel--a bad
# ekede f"typuentwf o-to,ngeuasrsh uctsc eel,"gl esy.
# boeanmnmen rmo  rto h
# alnkn
# ceirgen twed n awc rea"aoowlcirorreminoi eanitid cs fim"wiune efi yip -y, allive insaf. ise ad evto h"s- kp  avrigase,s rurs fne, e em-arofuimegs tom mafaldia aloitr tnd, henoante- honraldei
# epoch 45
# Epoch 1/1
# 200278/200278 [==============================] - 157s 784us/step - loss: 2.9219
# --Generating with seed:“sland of capri, that most terrible of all roman
# anachronisms”
# ----temperature: 0.2
# sland of capri, that most terrible of all roman
# anachronisms th eh and or oun tat r t the  whe er  sel ann one ofh  ann the  the he er  the ssod ane a nhelt eheine de inz tn on e th ere te  andr tofe th ant en the it the e and ait  thary thehe lo eatss a  the ondte  ther theeare the an the hers   ol techanet ol "h e tthec a ate of end re s  thhee  ew the ter thoh ohe al s tiee n  the o  ther e ane th en ho mard it he tha ante the than er ee  hehes   at  th
# ----temperature: 0.5
#  th en ho mard it he tha ante the than er ee  hehes   at  thas mdmet ? hhos n hx tslhitea caresn toree sol to ermee efäel ate of hors be "eha  wouel e ehetril he  an aultmhe is tfe  thaoh ouee ht oemortedhaine thess  m ongiicg w af el biaun tw chathee  an esr fecager at m;t aseot wite s,ediy ithetar   inilgn a  and a erestinrertac ele thut tuhrtee aset exs l and ischviett t! let ando ce ce on ehe r e  toig othe n houne ann uraeiser eesa the oltherhhander r
# ----temperature: 1.0
# r e  toig othe n houne ann uraeiser eesa the oltherhhander r ow mesliy owts itathaseutthglree, hlosuelg enr afornayvnuarit e  teudeer to h rh o mht thlrd al is henn
# piz init tonc
# elahdgtifaron increiklf, esnenlereuithj alcerhio:ete ondtucre l,s
# mocn elfstne:,ry hhieofin
#  ithhoa wolise slye heac ttt phoel  t eulncg ap, phi
#  re whannxi  . indharutei two ef eel andoe l l whndoc eakgaondith ssegm0 a m d f fhplmwe oboo r tet hro eryogl idr gsn ohar sp-tenebse
# ----temperature: 1.2
# m d f fhplmwe oboo r tet hro eryogl idr gsn ohar sp-tenebse mpnd afstatrpxg tatm umort o th0 eoistem7vof ,   vssrshecto
# ra-ngxeand aalfuowncsie taevyvrneto lencentm ,r to poloeilor cauwndevc1w
# anp, rncm sim  enelsychiupsshy
# ncchfags  thigltgofe rntuch.e to ohal ympoi au  bavil fialnlan-bs  anee si sseieiose
# hentoyt,
#  rrht oon4venqeise :io"c rtc mi algletde i usl amsfec saon osm nkme te stul ig
# whoom cs.ryo f
# ni,yteoosma(e"woen-n w
# rtumf  anot tahe
# hateps-n
# epoch 46
# Epoch 1/1
#  41600/200278 [=====>........................] - ETA: 2:03 - loss: 2.9452
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e99f46d8fee3> in <module>
#       6     print('epoch', epoch)
#       7     # 将模型在数据上拟合一次
# ----> 8     model.fit(x, y, batch_size=128, epochs=1)
#       9     # 随机选择一个文本种子
#      10     start_index = random.randint(0, len(text) - maxlen - 1)
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/deeplearning/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/anaconda3/envs/deeplearning/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/anaconda3/envs/deeplearning/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/anaconda3/envs/deeplearning/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/anaconda3/envs/deeplearning/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/deeplearning/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
可见：较小的温度值会得到极端重复和可预测的文本，但局部结构非常真实，特别是所有单词都是真正的英文单词
随着温度值越来越大，生成的文本也变得更有趣、更出人意料，甚至具有创造性，对于较大的温度，局部模式开始分解。
